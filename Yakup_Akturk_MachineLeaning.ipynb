# %% [markdown]
# <a href="https://colab.research.google.com/github/yakupusame/Stats-Canada/blob/main/Yakup_Akturk_MachineLeaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_1 = pd.read_csv('1.csv')
df_2 = pd.read_csv('2.csv')
df_3 = pd.read_csv('3.csv')
df_4 = pd.read_csv('5.csv')
df_5 = pd.read_csv('6.csv')
df_6 = pd.read_csv('7.csv')
df_7 = pd.read_csv('8.csv')
df_8 = pd.read_csv('9.csv')
df_9 = pd.read_csv('10.csv')
df_10 = pd.read_csv('11.csv')
df_11 = pd.read_csv('12.csv')
df_12 = pd.read_csv('13.csv')
df_13 = pd.read_csv('14.csv')
df_14 = pd.read_csv('15.csv')
df_15 = pd.read_csv('16.csv')
df_16 = pd.read_csv('17.csv')
df_17 = pd.read_csv('18.csv')
df_18 = pd.read_csv('19.csv')
df_19 = pd.read_csv('20.csv')
df_20 = pd.read_csv('21.csv')

# %%
df_1.head()
# Out:
#   REF_DATE                        GEO  ... TERMINATED DECIMALS
# 0  2015-10  Newfoundland and Labrador  ...        NaN        1
# 1  2015-11  Newfoundland and Labrador  ...        NaN        1
# 2  2015-12  Newfoundland and Labrador  ...        NaN        1
# 3  2016-01  Newfoundland and Labrador  ...        NaN        1
# 4  2016-02  Newfoundland and Labrador  ...        NaN        1
#
# [5 rows x 18 columns]

# %%
df_1.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_2.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_3.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_4.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_5.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_6.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_7.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_8.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_9.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_10.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_11.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_12.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_13.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_14.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_15.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_16.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_17.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_18.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_19.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)
df_20.drop(['DGUID','Labour force characteristics','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'],axis = 1 ,inplace = True)

# %%
df_1.head()
# Out:
#   REF_DATE                        GEO  ...          Age group  VALUE
# 0  2015-10  Newfoundland and Labrador  ...  15 years and over  122.5
# 1  2015-11  Newfoundland and Labrador  ...  15 years and over  119.0
# 2  2015-12  Newfoundland and Labrador  ...  15 years and over  115.2
# 3  2016-01  Newfoundland and Labrador  ...  15 years and over  107.7
# 4  2016-02  Newfoundland and Labrador  ...  15 years and over  108.7
#
# [5 rows x 6 columns]

# %%
df_1.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_2.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_3.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_4.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_5.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_6.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_7.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_8.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_9.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_10.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_11.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_12.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_13.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_14.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_15.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_16.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_17.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_18.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_19.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)
df_20.rename(columns={'REF_DATE': 'Date','GEO':'Province','North American Industry Classification System (NAICS)':'Industry','Age Group':'Age','VALUE':'Value'},inplace=True)

# %%
df_1.head()
# Out:
#       Date                   Province  ...          Age group  Value
# 0  2015-10  Newfoundland and Labrador  ...  15 years and over  122.5
# 1  2015-11  Newfoundland and Labrador  ...  15 years and over  119.0
# 2  2015-12  Newfoundland and Labrador  ...  15 years and over  115.2
# 3  2016-01  Newfoundland and Labrador  ...  15 years and over  107.7
# 4  2016-02  Newfoundland and Labrador  ...  15 years and over  108.7
#
# [5 rows x 6 columns]

# %%
df = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,
                df_10,df_11,df_12,df_13,df_14,df_15,df_16,df_17,df_18,df_19,df_20],axis = 0)
df
# Out:
#          Date                   Province  ...          Age group  Value
# 0     2015-10  Newfoundland and Labrador  ...  15 years and over  122.5
# 1     2015-11  Newfoundland and Labrador  ...  15 years and over  119.0
# 2     2015-12  Newfoundland and Labrador  ...  15 years and over  115.2
# 3     2016-01  Newfoundland and Labrador  ...  15 years and over  107.7
# 4     2016-02  Newfoundland and Labrador  ...  15 years and over  108.7
# ...       ...                        ...  ...                ...    ...
# 1703  2020-06           British Columbia  ...  15 years and over   50.7
# 1704  2020-07           British Columbia  ...  15 years and over   51.2
# 1705  2020-08           British Columbia  ...  15 years and over   52.4
# 1706  2020-09           British Columbia  ...  15 years and over   50.5
# 1707  2020-10           British Columbia  ...  15 years and over   53.0
#
# [34160 rows x 6 columns]

# %%
df.drop(['Age group'],axis = 1 , inplace = True)

# %%
df
# Out:
#          Date                   Province  ...      Sex  Value
# 0     2015-10  Newfoundland and Labrador  ...    Males  122.5
# 1     2015-11  Newfoundland and Labrador  ...    Males  119.0
# 2     2015-12  Newfoundland and Labrador  ...    Males  115.2
# 3     2016-01  Newfoundland and Labrador  ...    Males  107.7
# 4     2016-02  Newfoundland and Labrador  ...    Males  108.7
# ...       ...                        ...  ...      ...    ...
# 1703  2020-06           British Columbia  ...  Females   50.7
# 1704  2020-07           British Columbia  ...  Females   51.2
# 1705  2020-08           British Columbia  ...  Females   52.4
# 1706  2020-09           British Columbia  ...  Females   50.5
# 1707  2020-10           British Columbia  ...  Females   53.0
#
# [34160 rows x 5 columns]

# %%
df['Industry'].value_counts()
# Out:
# Professional, scientific and technical services [54]                           1220
# Non-durables [311-316, 322-326]                                                1220
# Forestry and logging and support activities for forestry [113, 1153]           1220
# Mining, quarrying, and oil and gas extraction [21, 2100]                       1220
# Finance and insurance [52]                                                     1220
# Durables [321, 327, 331-339]                                                   1220
# Finance, insurance, real estate, rental and leasing [52, 53]                   1220
# Retail trade [44-45]                                                           1220
# Services-producing sector                                                      1220
# Health care and social assistance [62]                                         1220
# Forestry, fishing, mining, quarrying, oil and gas [21, 113-114, 1153, 2100]    1220
# ...

# %%
df_jobs = pd.read_csv('job_skills.csv')
df_jobs
# Out:
#      Company  ...                           Preferred Qualifications
# 0     Google  ...  Experience in the business technology market a...
# 1     Google  ...  BSEE, BSME or BSIE degree.\nExperience of usin...
# 2     Google  ...  Experience partnering or consulting cross-func...
# 3     Google  ...  Experience as a software developer, architect,...
# 4     Google  ...  CTS Certification.\nExperience in the construc...
# ...      ...  ...                                                ...
# 1245  Google  ...  Investigative or Interview certification throu...
# 1246  Google  ...  Master’s degree.\nProficient in the use of com...
# 1247  Google  ...  Experience managing outsourced facilities serv...
# 1248  Google  ...  Experience working on international programs.\...
# 1249  Google  ...  Experience working on international programs.\...
#
# [1250 rows x 7 columns]

# %%
df_jobs['Category'].value_counts()
# Out:
# Sales & Account Management          168
# Marketing & Communications          165
# Finance                             115
# Technical Solutions                 101
# Business Strategy                    98
# People Operations                    86
# User Experience & Design             84
# Program Management                   74
# Partnerships                         60
# Product & Customer Support           50
# Legal & Government Relations         46
# Administrative                       40
# Sales Operations                     31
# Software Engineering                 31
# Hardware Engineering                 26
# Real Estate & Workplace Services     25
# Manufacturing & Supply Chain         16
# Technical Infrastructure             11
# Network Engineering                   6
# Technical Writing                     5
# Developer Relations                   5
# IT & Data Management                  5
# Data Center & Network                 2
# Name: Category, dtype: int64

# %%
df
# Out:
#          Date                   Province  ...      Sex  Value
# 0     2015-10  Newfoundland and Labrador  ...    Males  122.5
# 1     2015-11  Newfoundland and Labrador  ...    Males  119.0
# 2     2015-12  Newfoundland and Labrador  ...    Males  115.2
# 3     2016-01  Newfoundland and Labrador  ...    Males  107.7
# 4     2016-02  Newfoundland and Labrador  ...    Males  108.7
# ...       ...                        ...  ...      ...    ...
# 1703  2020-06           British Columbia  ...  Females   50.7
# 1704  2020-07           British Columbia  ...  Females   51.2
# 1705  2020-08           British Columbia  ...  Females   52.4
# 1706  2020-09           British Columbia  ...  Females   50.5
# 1707  2020-10           British Columbia  ...  Females   53.0
#
# [34160 rows x 5 columns]

# %%
# Employment dropped in all industries during COVID-19
fig, ax = plt.subplots(figsize=(30,20))
df.groupby(['Date','Industry']).mean()['Value'].unstack().plot(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(30,10))
df.groupby(['Date','Sex']).mean()['Value'].unstack().plot(ax=ax)

# %%
# We can see that most of the employment occurs in Ontario and Quebec 
fig, ax = plt.subplots(figsize=(30,10))
df.groupby(['Date','Province']).mean()['Value'].unstack().plot(ax=ax)

# %%
df_jobs
# Out:
#      Company  ...                           Preferred Qualifications
# 0     Google  ...  Experience in the business technology market a...
# 1     Google  ...  BSEE, BSME or BSIE degree.\nExperience of usin...
# 2     Google  ...  Experience partnering or consulting cross-func...
# 3     Google  ...  Experience as a software developer, architect,...
# 4     Google  ...  CTS Certification.\nExperience in the construc...
# ...      ...  ...                                                ...
# 1245  Google  ...  Investigative or Interview certification throu...
# 1246  Google  ...  Master’s degree.\nProficient in the use of com...
# 1247  Google  ...  Experience managing outsourced facilities serv...
# 1248  Google  ...  Experience working on international programs.\...
# 1249  Google  ...  Experience working on international programs.\...
#
# [1250 rows x 7 columns]
